# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json
import pandas as pd
url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'20',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '944457f0-8424-4dba-8738-51fab9019942',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  df = pd.DataFrame(data['data'])
  print(df)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
# Out:
#       id             name symbol                  slug  num_market_pairs  \
# 0      1          Bitcoin    BTC               bitcoin             10142
# 1   1027         Ethereum    ETH              ethereum              6699
# 2    825           Tether   USDT                tether             50757
# 3   1839              BNB    BNB                   bnb              1242
# 4   3408         USD Coin   USDC              usd-coin             11440
# 5     52              XRP    XRP                   xrp               927
# 6   2010          Cardano    ADA               cardano               761
# 7     74         Dogecoin   DOGE              dogecoin               680
# 8   3890          Polygon  MATIC               polygon               648
# 9   5426           Solana    SOL                solana               454
# 10  6636         Polkadot    DOT          polkadot-new               494
# 11  4687      Binance USD   BUSD           binance-usd              6534
# 12     2         Litecoin    LTC              litecoin               899
# 13  5994        Shiba Inu   SHIB             shiba-inu               499
# 14  1958             TRON    TRX                  tron               747
# 15  5805        Avalanche   AVAX             avalanche               398
# 16  4943              Dai    DAI  multi-collateral-dai              2102
# 17  3717  Wrapped Bitcoin   WBTC       wrapped-bitcoin              1065
# 18  1975        Chainlink   LINK             chainlink              1063
# 19  7083          Uniswap    UNI               uniswap               643
#
#                   date_added  \
# 0   2010-07-13T00:00:00.000Z
# 1   2015-08-07T00:00:00.000Z
# 2   2015-02-25T00:00:00.000Z
# 3   2017-07-25T00:00:00.000Z
# 4   2018-10-08T00:00:00.000Z
# 5   2013-08-04T00:00:00.000Z
# 6   2017-10-01T00:00:00.000Z
# 7   2013-12-15T00:00:00.000Z
# 8   2019-04-28T00:00:00.000Z
# 9   2020-04-10T00:00:00.000Z
# 10  2020-08-19T00:00:00.000Z
# 11  2019-09-20T00:00:00.000Z
# 12  2013-04-28T00:00:00.000Z
# 13  2020-08-01T00:00:00.000Z
# 14  2017-09-13T00:00:00.000Z
# 15  2020-07-13T00:00:00.000Z
# 16  2019-11-22T00:00:00.000Z
# 17  2019-01-30T00:00:00.000Z
# 18  2017-09-20T00:00:00.000Z
# 19  2020-09-17T00:00:00.000Z
#
#                                                  tags    max_supply  \
# 0   [mineable, pow, sha-256, store-of-value, state...  2.100000e+07
# 1   [pos, smart-contracts, ethereum-ecosystem, coi...           NaN
# 2   [payments, stablecoin, asset-backed-stablecoin...           NaN
# 3   [marketplace, centralized-exchange, payments, ...           NaN
# 4   [medium-of-exchange, stablecoin, asset-backed-...           NaN
# 5   [medium-of-exchange, enterprise-solutions, arr...  1.000000e+11
# 6   [dpos, pos, platform, research, smart-contract...  4.500000e+10
# 7   [mineable, pow, scrypt, medium-of-exchange, me...           NaN
# 8   [platform, enterprise-solutions, zero-knowledg...  1.000000e+10
# 9   [pos, platform, solana-ecosystem, cms-holdings...           NaN
# 10  [substrate, polkadot, binance-chain, polkadot-...           NaN
# 11  [stablecoin, asset-backed-stablecoin, binance-...           NaN
# 12        [mineable, pow, scrypt, medium-of-exchange]  8.400000e+07
# 13      [memes, ethereum-ecosystem, doggone-doggerel]           NaN
# 14                  [media, payments, tron-ecosystem]           NaN
# 15  [defi, smart-contracts, three-arrows-capital-p...  7.200000e+08
# 16  [defi, stablecoin, asset-backed-stablecoin, et...           NaN
# 17  [medium-of-exchange, defi, wrapped-tokens, fan...           NaN
# 18  [platform, defi, oracles, smart-contracts, sub...  1.000000e+09
# 19  [decentralized-exchange-dex-token, defi, dao, ...  1.000000e+09
#
#     circulating_supply  total_supply  \
# 0         1.933815e+07  1.933815e+07
# 1         1.204578e+08  1.204578e+08
# 2         8.000456e+10  8.309174e+10
# 3         1.578874e+08  1.599800e+08
# 4         3.262373e+10  3.262373e+10
# 5         5.164939e+10  9.998904e+10
# 6         3.475449e+10  3.566069e+10
# 7         1.388186e+11  1.388186e+11
# 8         9.080469e+09  1.000000e+10
# 9         3.871818e+08  5.393127e+08
# 10        1.173502e+09  1.299981e+09
# 11        7.205816e+09  7.205816e+09
# 12        7.264061e+07  8.400000e+07
# 13        5.895430e+14  5.896079e+14
# 14        9.095053e+10  9.095053e+10
# 15        3.261196e+08  4.221824e+08
# 16        5.282275e+09  5.282275e+09
# 17        1.510506e+05  1.510506e+05
# 18        5.171000e+08  1.000000e+09
# 19        5.774867e+08  1.000000e+09
#
#                                              platform  cmc_rank  \
# 0                                                None         1
# 1                                                None         2
# 2   {'id': 1027, 'name': 'Ethereum', 'symbol': 'ET...         3
# 3                                                None         4
# 4   {'id': 1027, 'name': 'Ethereum', 'symbol': 'ET...         5
# 5                                                None         6
# 6                                                None         7
# 7                                                None         8
# 8                                                None         9
# 9                                                None        10
# 10                                               None        11
# 11  {'id': 1839, 'name': 'BNB', 'symbol': 'BNB', '...        12
# 12                                               None        13
# 13  {'id': 1027, 'name': 'Ethereum', 'symbol': 'ET...        14
# 14                                               None        15
# 15                                               None        16
# 16  {'id': 1027, 'name': 'Ethereum', 'symbol': 'ET...        17
# 17  {'id': 1027, 'name': 'Ethereum', 'symbol': 'ET...        18
# 18  {'id': 1027, 'name': 'Ethereum', 'symbol': 'ET...        19
# 19  {'id': 1027, 'name': 'Ethereum', 'symbol': 'ET...        20
#
#     self_reported_circulating_supply  self_reported_market_cap  tvl_ratio  \
# 0                                NaN                       NaN        NaN
# 1                                NaN                       NaN        NaN
# 2                                NaN                       NaN        NaN
# 3                                NaN                       NaN        NaN
# 4                                NaN                       NaN        NaN
# 5                                NaN                       NaN        NaN
# 6                                NaN                       NaN        NaN
# 7                                NaN                       NaN        NaN
# 8                                NaN                       NaN        NaN
# 9                                NaN                       NaN        NaN
# 10                               NaN                       NaN        NaN
# 11                               NaN                       NaN        NaN
# 12                               NaN                       NaN        NaN
# 13                               NaN                       NaN        NaN
# 14                      7.165966e+10              4.737570e+09        NaN
# 15                               NaN                       NaN        NaN
# 16                               NaN                       NaN        NaN
# 17                               NaN                       NaN        NaN
# 18                               NaN                       NaN        NaN
# 19                               NaN                       NaN   0.889914
#
#                 last_updated  \
# 0   2023-04-05T23:47:00.000Z
# 1   2023-04-05T23:47:00.000Z
# 2   2023-04-05T23:47:00.000Z
# 3   2023-04-05T23:47:00.000Z
# 4   2023-04-05T23:47:00.000Z
# 5   2023-04-05T23:47:00.000Z
# 6   2023-04-05T23:47:00.000Z
# 7   2023-04-05T23:47:00.000Z
# 8   2023-04-05T23:47:00.000Z
# 9   2023-04-05T23:47:00.000Z
# 10  2023-04-05T23:47:00.000Z
# 11  2023-04-05T23:47:00.000Z
# 12  2023-04-05T23:47:00.000Z
# 13  2023-04-05T23:47:00.000Z
# 14  2023-04-05T23:47:00.000Z
# 15  2023-04-05T23:47:00.000Z
# 16  2023-04-05T23:47:00.000Z
# 17  2023-04-05T23:47:00.000Z
# 18  2023-04-05T23:47:00.000Z
# 19  2023-04-05T23:47:00.000Z
#
#                                                 quote
# 0   {'USD': {'price': 28202.959890371734, 'volume_...
# 1   {'USD': {'price': 1912.7237808108805, 'volume_...
# 2   {'USD': {'price': 0.9998776448535202, 'volume_...
# 3   {'USD': {'price': 314.3368163243189, 'volume_2...
# 4   {'USD': {'price': 0.9996133825336022, 'volume_...
# 5   {'USD': {'price': 0.5061600703533566, 'volume_...
# 6   {'USD': {'price': 0.3925424250957467, 'volume_...
# 7   {'USD': {'price': 0.09346103217308649, 'volume...
# 8   {'USD': {'price': 1.1424894388369662, 'volume_...
# 9   {'USD': {'price': 21.010528334470703, 'volume_...
# 10  {'USD': {'price': 6.407101775999049, 'volume_2...
# 11  {'USD': {'price': 0.9996970044047735, 'volume_...
# 12  {'USD': {'price': 92.64905878095982, 'volume_2...
# 13  {'USD': {'price': 1.1254347500868544e-05, 'vol...
# 14  {'USD': {'price': 0.06611208601286221, 'volume...
# 15  {'USD': {'price': 18.005675666245107, 'volume_...
# 16  {'USD': {'price': 0.9995374960303997, 'volume_...
# 17  {'USD': {'price': 28262.90877149358, 'volume_2...
# 18  {'USD': {'price': 7.332477044588316, 'volume_2...
# 19  {'USD': {'price': 6.23436278566042, 'volume_24...
